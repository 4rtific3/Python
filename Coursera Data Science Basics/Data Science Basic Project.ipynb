# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patch
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("csv files/Banknote-authentication-dataset-.csv")
V1 = data["V1"]
V2 = data["V2"]
data
# Out:
#            V1        V2
# 0     3.62160   8.66610
# 1     4.54590   8.16740
# 2     3.86600  -2.63830
# 3     3.45660   9.52280
# 4     0.32924  -4.45520
# ...       ...       ...
# 1367  0.40614   1.34920
# 1368 -1.38870  -4.87730
# 1369 -3.75030 -13.45860
# 1370 -3.56370  -8.38270
# 1371 -2.54190  -0.65804
#
# [1372 rows x 2 columns]

# %%
data.describe()
# Out:
#                 V1           V2
# count  1372.000000  1372.000000
# mean      0.433735     1.922353
# std       2.842763     5.869047
# min      -7.042100   -13.773100
# 25%      -1.773000    -1.708200
# 50%       0.496180     2.319650
# 75%       2.821475     6.814625
# max       6.824800    12.951600

# %%
array = np.array(data)
array
# Out:
# array([[  3.6216 ,   8.6661 ],
#        [  4.5459 ,   8.1674 ],
#        [  3.866  ,  -2.6383 ],
#        ...,
#        [ -3.7503 , -13.4586 ],
#        [ -3.5637 ,  -8.3827 ],
#        [ -2.5419 ,  -0.65804]])

# %%
mean = array.mean(0)
mean
# Out:
# array([0.43373526, 1.92235312])

# %%
stdev = array.std(0)
stdev
# Out:
# array([2.84172641, 5.86690749])

# %%
plt.scatter(V1, V2)
plt.scatter(mean[0], mean[1])
plt.show()

# %%
array_min = array.min(0)
array_max = array.max(0)
normed = (array - array_min) / (array_max - array_min)
print(normed)
# Out:
# [[0.76900389 0.83964273]
#  [0.83565902 0.82098209]
#  [0.78662859 0.41664827]
#  ...
#  [0.23738543 0.01176814]
#  [0.25084193 0.20170105]
#  [0.32452819 0.49074676]]

# %%
plt.scatter(normed[:,0], normed[:,1])
plt.show()

# %%
array_min = array.min(0)
array_max = array.max(0)
normed = (4 * (array - array_min) / (array_max - array_min)) - 2

plt.scatter(normed[:,0], normed[:,1])
plt.show()

# %%
V1_V2 = np.column_stack((V1,V2))
km = KMeans(n_clusters=2).fit(V1_V2)
clusters = km.cluster_centers_
print(clusters)
# Out:
# [[-0.14742954 -3.56804932]
#  [ 0.86960885  6.04015495]]

# %%
plt.scatter(V1, V2)
plt.scatter(clusters[:,0], clusters[:,1])
plt.show()

# %% [markdown]
# Not standardising the data resulted in a skewed weighting of the standard deviation and hence closer K-Means values

# %%
V1_V2 = np.column_stack((normed[:,0],normed[:,1]))
km = KMeans(n_clusters=2).fit(V1_V2)
clusters = km.cluster_centers_
plt.scatter(normed[:,0],normed[:,1])
plt.scatter(clusters[:,0], clusters[:,1])
plt.show()
